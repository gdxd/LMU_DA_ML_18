# %%
# analyse old faithful data with pandas
import pandas as pd
import matplotlib.pyplot as plt
# can read data directly from web
# interpret as csv format 
# and import as Pandas dataframe 
d=pd.read_csv('https://people.sc.fsu.edu/~jburkardt/data/csv/faithful.csv')
d.columns=['Index','El','Ew']

ElNext=d.El[1:] # get duration of eruption starting w/ 2nd
ElNext.index=range(len(ElNext)) # reset index
d['ElNext']=ElNext
d.plot.scatter('El','ElNext')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 4 columns):
# Index     272 non-null int64
# El        272 non-null float64
# Ew        272 non-null int64
# ElNext    271 non-null float64
# dtypes: float64(2), int64(2)
# memory usage: 8.6 KB
